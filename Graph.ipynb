# %%
import matplotlib.pyplot as plt
import numpy as np

# 准备数据
metrics = ['Accuracy', 'Precision', 'F1-score', 'Specificity', 'Sensitivity']
values = [0.8273, 0.8117, 0.8389, 0.8321, 0.8221]

# 设置画布大小和分辨率
plt.figure(figsize=(8, 5), dpi=100)

# x轴位置
x_positions = np.arange(len(metrics))

# 绘制柱状图
plt.bar(x_positions, values, color='skyblue', width=0.6, edgecolor='black')

# 设置x轴刻度和标签
plt.xticks(x_positions, metrics, rotation=45, ha='right')

# y轴范围(可根据需要调整)
plt.ylim([0.0, 1.0])

# 添加数值标注
for i, v in enumerate(values):
    plt.text(i, v + 0.005, f"{v:.4f}", ha='center', color='black', fontsize=10)

# 添加标题和坐标轴标签
plt.title('Model Performance Metrics')
plt.ylabel('Score')

# 去掉上、右边框线条，使图表更美观
plt.box(False)

# 显示图表
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# 准备数据
metrics = ['Accuracy', 'Precision', 'F1-score', 'Specificity', 'Sensitivity']

# 假设有三个模型的指标数据（根据实际情况进行替换）
model_names = ['Model A', 'Model B', 'Model C', 'Our Sentiment Model']
model_A_scores = [0.8273, 0.8117, 0.8389, 0.8321, 0.8221]
model_B_scores = [0.9350, 0.9101, 0.9435, 0.8360, 0.8290]
model_C_scores = [0.7990, 0.7750, 0.8300, 0.6255, 0.7155]
Our_model(SCB) = [0.8534, 0.8917, 0.8200, 0.8255, 0.8055]

all_scores = [model_A_scores, model_B_scores, model_C_scores, Our_model]

# 每个指标对应的x轴坐标
x_positions = np.arange(len(metrics))

# 每组柱子的总数（即模型数）
num_models = len(model_names)

# 柱子宽度
bar_width = 0.2

# 设置画布大小和分辨率
plt.figure(figsize=(10, 6), dpi=100)

# 对每个模型绘制柱状图
for i, scores in enumerate(all_scores):
    # 柱子在x方向的位置偏移，以使不同模型分组排列
    offset = (i - (num_models - 1) / 2) * bar_width
    plt.bar(x_positions + offset, scores, width=bar_width, label=model_names[i], edgecolor='black')

# 设置x轴刻度和标签
plt.xticks(x_positions, metrics, rotation=45, ha='right')

# 设置y轴范围(可根据需要调整)
plt.ylim([0.0, 1.0])

# 添加标题和坐标轴标签
plt.title('Comparison of Model Performance Metrics')
plt.ylabel('Score')

# 添加图例
plt.legend()

# 添加数值标注（可选）
for i, scores in enumerate(all_scores):
    offset = (i - (num_models - 1) / 2) * bar_width
    for j, v in enumerate(scores):
        plt.text(x_positions[j] + offset, v + 0.005, f"{v:.4f}", ha='center', color='black', fontsize=9, rotation=90)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# 准备数据
metrics = ['Accuracy', 'Precision', 'F1-score', 'Specificity', 'Sensitivity']

# 假设有四个模型的指标数据（根据实际情况进行替换）
model_names = ['', 'Model B', 'Model C', '', 'Our Sentiment Model']
model_A_scores = [0.8273, 0.8117, 0.8389, 0.8321, 0.8221]
model_B_scores = [0.9350, 0.9101, 0.9435, 0.8360, 0.8290]
model_C_scores = [0.7990, 0.7750, 0.8300, 0.6255, 0.7155]
Our_model = [0.8534, 0.8917, 0.8200, 0.8255, 0.8055]

all_scores = [model_A_scores, model_B_scores, model_C_scores, Our_model]

# 每个指标对应的x轴坐标
x_positions = np.arange(len(metrics))

# 每组柱子的总数（即模型数）
num_models = len(model_names)

# 柱子宽度
bar_width = 0.2

# 自定义每个模型的颜色
colors = ['lightblue', 'red', 'orange', 'pink']

# 设置画布大小和分辨率
plt.figure(figsize=(10, 6), dpi=100)

# 对每个模型绘制柱状图
for i, scores in enumerate(all_scores):
    # 柱子在x方向的位置偏移，以使不同模型分组排列
    offset = (i - (num_models - 1) / 2) * bar_width
    plt.bar(x_positions + offset, scores, width=bar_width, label=model_names[i], 
            edgecolor='black', color=colors[i])

# 设置x轴刻度和标签
plt.xticks(x_positions, metrics, rotation=45, ha='right')

# 设置y轴范围(可根据需要调整)
plt.ylim([0.0, 1.0])

# 添加标题和坐标轴标签
plt.title('Comparison of Model Performance Metrics')
plt.ylabel('Score')

# 添加图例
plt.legend()

# 添加数值标注（可选）
for i, scores in enumerate(all_scores):
    offset = (i - (num_models - 1) / 2) * bar_width
    for j, v in enumerate(scores):
        plt.text(x_positions[j] + offset, v + 0.005, f"{v:.4f}", ha='center', 
                 color='black', fontsize=9, rotation=90)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# 准备数据
metrics = ['Accuracy', 'Precision', 'F1-score', 'Specificity', 'Sensitivity']

model_names = ['Model A', 'Model B', 'Model C', 'Our Sentiment Model']
model_A_scores = [0.8273, 0.8117, 0.8389, 0.8321, 0.8221]
model_B_scores = [0.9350, 0.9101, 0.9435, 0.8360, 0.8290]
model_C_scores = [0.7990, 0.7750, 0.8300, 0.6255, 0.7155]
Our_model = [0.8534, 0.8917, 0.8200, 0.8255, 0.8055]

all_scores = [model_A_scores, model_B_scores, model_C_scores, Our_model]

# 每个指标对应的x轴坐标
x_positions = np.arange(len(metrics))

# 每组柱子的总数（即模型数）
num_models = len(model_names)

# 柱子宽度
bar_width = 0.2

# 自定义每个模型的颜色
colors = ['lightblue', 'red', 'orange', 'pink']

# 设置画布大小（单栏宽度3.5英寸）和较高分辨率
plt.figure(figsize=(3.5, 3.5), dpi=300)

# 对每个模型绘制柱状图
for i, scores in enumerate(all_scores):
    offset = (i - (num_models - 1) / 2) * bar_width
    plt.bar(x_positions + offset, scores, width=bar_width, label=model_names[i], 
            edgecolor='black', color=colors[i])

# 设置x轴刻度和标签
plt.xticks(x_positions, metrics, rotation=45, ha='right')

# 设置y轴范围(可根据需要调整)
plt.ylim([0.0, 1.0])

# 添加标题和坐标轴标签
plt.title('Comparison of Model Performance Metrics', fontsize=10)
plt.ylabel('Score', fontsize=9)

# 调整刻度文字大小以适应较小画幅
plt.tick_params(axis='x', labelsize=8)
plt.tick_params(axis='y', labelsize=8)

# 添加图例（可适当缩小图例字体）
plt.legend(fontsize=8)

# 添加数值标注（可选）
for i, scores in enumerate(all_scores):
    offset = (i - (num_models - 1) / 2) * bar_width
    for j, v in enumerate(scores):
        plt.text(x_positions[j] + offset, v + 0.005, f"{v:.4f}", ha='center', 
                 color='black', fontsize=6, rotation=90)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# 准备数据
metrics = ['Accuracy', 'Precision', 'F1-score', 'Specificity', 'Sensitivity']

model_names = ['Model A', 'Model B', 'Model C', 'Our Sentiment Model']
model_A_scores = [0.8273, 0.8117, 0.8389, 0.8321, 0.8221]
model_B_scores = [0.9350, 0.9101, 0.9435, 0.8360, 0.8290]
model_C_scores = [0.7990, 0.7750, 0.8300, 0.6255, 0.7155]
Our_model = [0.8534, 0.8917, 0.8200, 0.8255, 0.8055]

all_scores = [model_A_scores, model_B_scores, model_C_scores, Our_model]

# 每个指标对应的x轴坐标
x_positions = np.arange(len(metrics))

# 每组柱子的总数（即模型数）
num_models = len(model_names)

# 柱子宽度
bar_width = 0.2

# 自定义每个模型的颜色
colors = ['lightblue', 'red', 'orange', 'pink']

# 设置画布大小（单栏宽度3.5英寸）和较高分辨率
plt.figure(figsize=(3.5, 3.5), dpi=300)

# 对每个模型绘制柱状图
for i, scores in enumerate(all_scores):
    offset = (i - (num_models - 1) / 2) * bar_width
    plt.bar(x_positions + offset, scores, width=bar_width, label=model_names[i], 
            edgecolor='black', color=colors[i])

# 设置x轴刻度和标签
plt.xticks(x_positions, metrics, rotation=45, ha='right')

# 设置y轴范围(可根据需要调整)
plt.ylim([0.0, 1.0])

# 添加标题和坐标轴标签
plt.title('Comparison of Model Performance Metrics', fontsize=10)
plt.ylabel('Score', fontsize=9)

# 调整刻度文字大小以适应较小画幅
plt.tick_params(axis='x', labelsize=8)
plt.tick_params(axis='y', labelsize=8)

# 添加图例（可适当缩小图例字体）
plt.legend(fontsize=8)

# 添加数值标注（可选，保留两位小数）
for i, scores in enumerate(all_scores):
    offset = (i - (num_models - 1) / 2) * bar_width
    for j, v in enumerate(scores):
        plt.text(x_positions[j] + offset, v + 0.005, f"{v:.2f}", ha='center', 
                 color='black', fontsize=6, rotation=90)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# 准备数据
metrics = ['Accuracy', 'Precision', 'F1-score', 'Specificity', 'Sensitivity']

model_names = ['Model A', 'Model B', 'Model C', 'Our Sentiment Model']
model_A_scores = [0.8273, 0.8117, 0.8389, 0.8321, 0.8221]
model_B_scores = [0.9350, 0.9101, 0.9435, 0.8360, 0.8290]
model_C_scores = [0.7990, 0.7750, 0.8300, 0.6255, 0.7155]
Our_model = [0.8534, 0.8917, 0.8200, 0.8255, 0.8055]

all_scores = [model_A_scores, model_B_scores, model_C_scores, Our_model]

# 每个指标对应的x轴坐标
x_positions = np.arange(len(metrics))

# 每组柱子的总数（即模型数）
num_models = len(model_names)

# 柱子宽度
bar_width = 0.2

# 自定义每个模型的颜色
colors = ['lightblue', 'red', 'orange', 'pink']

# 设置画布大小（单栏宽度3.5英寸）和较高分辨率
plt.figure(figsize=(3.5, 3.5), dpi=300)

# 对每个模型绘制柱状图
for i, scores in enumerate(all_scores):
    offset = (i - (num_models - 1) / 2) * bar_width
    plt.bar(x_positions + offset, scores, width=bar_width, label=model_names[i], 
            edgecolor='black', color=colors[i])

# 设置x轴刻度和标签
plt.xticks(x_positions, metrics, rotation=45, ha='right')

# 设置y轴范围(可根据需要调整)
plt.ylim([0.0, 1.0])

# 添加标题和坐标轴标签
plt.title('Comparison of Model Performance Metrics', fontsize=10)
plt.ylabel('Score', fontsize=9)

# 将刻度字体变小，比如从8改为6
plt.tick_params(axis='x', labelsize=6)
plt.tick_params(axis='y', labelsize=6)

# 添加图例（可适当缩小图例字体）
plt.legend(fontsize=8)

# 添加数值标注（保留两位小数）
for i, scores in enumerate(all_scores):
    offset = (i - (num_models - 1) / 2) * bar_width
    for j, v in enumerate(scores):
        plt.text(x_positions[j] + offset, v + 0.005, f"{v:.2f}", ha='center', 
                 color='black', fontsize=6, rotation=90)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# 准备数据
metrics = ['Accuracy', 'Precision', 'F1-score', 'Specificity', 'Sensitivity']

model_names = ['Model A', 'Model B', 'Model C', 'Our Sentiment Model']
model_A_scores = [0.8273, 0.8117, 0.8389, 0.8321, 0.8221]
model_B_scores = [0.9350, 0.9101, 0.9435, 0.8360, 0.8290]
model_C_scores = [0.7990, 0.7750, 0.8300, 0.6255, 0.7155]
Our_model = [0.8534, 0.8917, 0.8200, 0.8255, 0.8055]

all_scores = [model_A_scores, model_B_scores, model_C_scores, Our_model]

# 每个指标对应的x轴坐标
x_positions = np.arange(len(metrics))

# 每组柱子的总数（即模型数）
num_models = len(model_names)

# 柱子宽度
bar_width = 0.2

# 自定义每个模型的颜色
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728']

# 设置画布大小（单栏宽度3.5英寸，高度设为5英寸）和较高分辨率
plt.figure(figsize=(3.5, 5), dpi=300)

# 对每个模型绘制柱状图
for i, scores in enumerate(all_scores):
    offset = (i - (num_models - 1) / 2) * bar_width
    plt.bar(x_positions + offset, scores, width=bar_width, label=model_names[i], 
            edgecolor='black', color=colors[i])

# 设置x轴刻度和标签
plt.xticks(x_positions, metrics, rotation=45, ha='right')

# 设置y轴范围(可根据需要调整)
plt.ylim([0.0, 1.0])

# 添加标题和坐标轴标签
plt.title('Comparison of Model Performance Metrics', fontsize=10)
plt.ylabel('Score', fontsize=9)

# 调整刻度文字大小以适应较小画幅
plt.tick_params(axis='x', labelsize=8)
plt.tick_params(axis='y', labelsize=8)

# 添加图例（可适当缩小图例字体）
plt.legend(fontsize=8)

# 添加数值标注（可选）
for i, scores in enumerate(all_scores):
    offset = (i - (num_models - 1) / 2) * bar_width
    for j, v in enumerate(scores):
        plt.text(x_positions[j] + offset, v + 0.005, f"{v:.4f}", ha='center', 
                 color='black', fontsize=6, rotation=90)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# 准备数据
metrics = ['Accuracy', 'Precision', 'F1-score', 'Specificity', 'Sensitivity']

model_names = ['Model A', 'Model B', 'Model C', 'Our Sentiment Model']
model_A_scores = [0.8273, 0.8117, 0.8389, 0.8321, 0.8221]
model_B_scores = [0.9350, 0.9101, 0.9435, 0.8360, 0.8290]
model_C_scores = [0.7990, 0.7750, 0.8300, 0.6255, 0.7155]
Our_model = [0.8534, 0.8917, 0.8200, 0.8255, 0.8055]

all_scores = [model_A_scores, model_B_scores, model_C_scores, Our_model]

# 每个指标对应的x轴坐标
x_positions = np.arange(len(metrics))

# 每组柱子的总数（即模型数）
num_models = len(model_names)

# 柱子宽度
bar_width = 0.2

# 自定义每个模型的颜色
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728']

# 设置画布大小（宽3.5英寸，高7英寸）和较高分辨率
plt.figure(figsize=(3.5, 7), dpi=300)

# 对每个模型绘制柱状图
for i, scores in enumerate(all_scores):
    offset = (i - (num_models - 1) / 2) * bar_width
    plt.bar(x_positions + offset, scores, width=bar_width, label=model_names[i], 
            edgecolor='black', color=colors[i])

# 设置x轴刻度和标签
plt.xticks(x_positions, metrics, rotation=45, ha='right')

# 设置y轴范围(可根据需要调整)
plt.ylim([0.0, 1.0])

# 添加标题和坐标轴标签
plt.title('Comparison of Model Performance Metrics', fontsize=10)
plt.ylabel('Score', fontsize=9)

# 调整刻度文字大小以适应较小画幅
plt.tick_params(axis='x', labelsize=8)
plt.tick_params(axis='y', labelsize=8)

# 添加图例（可适当缩小图例字体）
plt.legend(fontsize=8)

# 添加数值标注（可选）
for i, scores in enumerate(all_scores):
    offset = (i - (num_models - 1) / 2) * bar_width
    for j, v in enumerate(scores):
        plt.text(x_positions[j] + offset, v + 0.005, f"{v:.4f}", ha='center', 
                 color='black', fontsize=6, rotation=90)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# 准备数据
metrics = ['Accuracy', 'Precision', 'F1-score', 'Specificity', 'Sensitivity']

model_names = ['GP', 'GFT', 'RP', 'RFT', 'SCB']
model_A_scores = [0.8273, 0.8117, 0.8389, 0.8321, 0.8221]
model_B_scores = [0.9350, 0.9101, 0.9435, 0.8360, 0.8290]
model_C_scores = [0.7990, 0.7750, 0.8300, 0.6255, 0.7155]
model_D_scores = [0.7190, 0.7950, 0.8100, 0.7255, 0.8155]
Our_model = [0.8534, 0.8917, 0.8200, 0.8255, 0.8055]

all_scores = [model_A_scores, model_B_scores, model_C_scores, model_D_scores, Our_model]

# 每个指标对应的x轴坐标
x_positions = np.arange(len(metrics))

# 每组柱子的总数（即模型数）
num_models = len(model_names)

# 柱子宽度
bar_width = 0.2

# 自定义每个模型的颜色
colors = ['lightblue', 'red', 'orange', 'pink', 'purple']

# 将画布宽度增加到5英寸，高度保持3.5英寸
plt.figure(figsize=(5, 3.5), dpi=300)

# 对每个模型绘制柱状图
for i, scores in enumerate(all_scores):
    offset = (i - (num_models - 1) / 2) * bar_width
    plt.bar(x_positions + offset, scores, width=bar_width, label=model_names[i], 
            edgecolor='black', color=colors[i])

# 设置x轴刻度和标签
plt.xticks(x_positions, metrics, rotation=45, ha='right')

# 设置y轴范围(可根据需要调整)
plt.ylim([0.0, 1.0])

# 添加标题和坐标轴标签
plt.title('Comparison of Model Performance Metrics', fontsize=10)
plt.ylabel('Score', fontsize=9)

# 将刻度字体设小一些
plt.tick_params(axis='x', labelsize=6)
plt.tick_params(axis='y', labelsize=6)

# 添加图例
plt.legend(fontsize=8)

# 添加数值标注（保留两位小数）
for i, scores in enumerate(all_scores):
    offset = (i - (num_models - 1) / 2) * bar_width
    for j, v in enumerate(scores):
        plt.text(x_positions[j] + offset, v + 0.005, f"{v:.2f}", ha='center', 
                 color='black', fontsize=6, rotation=90)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

metrics = ['Accuracy', 'Precision', 'F1-score', 'Specificity', 'Sensitivity']
model_names = ['GP', 'GFT', 'RP', 'RFT', 'SCB']
model_A_scores = [0.8273, 0.8117, 0.8389, 0.8321, 0.8221]
model_B_scores = [0.9350, 0.9101, 0.9435, 0.8360, 0.8290]
model_C_scores = [0.7990, 0.7750, 0.8300, 0.6255, 0.7155]
model_D_scores = [0.7190, 0.7950, 0.8100, 0.7255, 0.8155]
Our_model = [0.8534, 0.8917, 0.8200, 0.8255, 0.8055]

all_scores = [model_A_scores, model_B_scores, model_C_scores, model_D_scores, Our_model]

x_positions = np.arange(len(metrics))
num_models = len(model_names)

# 将柱子宽度变窄
bar_width = 0.1

colors = ['lightblue', 'red', 'orange', 'pink', 'purple']

# 调整图形尺寸，减小高度
plt.figure(figsize=(5, 2), dpi=300)

for i, scores in enumerate(all_scores):
    offset = (i - (num_models - 1) / 2) * bar_width
    plt.bar(x_positions + offset, scores, width=bar_width, label=model_names[i], 
            edgecolor='black', color=colors[i])

plt.xticks(x_positions, metrics, rotation=45, ha='right')

# 适当减少Y轴上限，让柱子看起来更矮
plt.ylim([0.0, 1.0])

plt.title('Comparison of Model Performance Metrics', fontsize=10)
plt.ylabel('Score', fontsize=9)

plt.tick_params(axis='x', labelsize=6)
plt.tick_params(axis='y', labelsize=6)

plt.legend(fontsize=8)

for i, scores in enumerate(all_scores):
    offset = (i - (num_models - 1) / 2) * bar_width
    for j, v in enumerate(scores):
        plt.text(x_positions[j] + offset, v + 0.005, f"{v:.2f}", ha='center', 
                 color='black', fontsize=6, rotation=90)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# 准备数据
metrics = ['Accuracy', 'Precision', 'F1-score', 'Specificity', 'Sensitivity']

model_names = ['GP', 'GFT', 'RP', 'RFT', 'SCB']
model_A_scores = [0.8273, 0.8117, 0.8389, 0.8321, 0.8221]
model_B_scores = [0.9350, 0.9101, 0.9435, 0.8360, 0.8290]
model_C_scores = [0.7990, 0.7750, 0.8300, 0.6255, 0.7155]
model_D_scores = [0.7190, 0.7950, 0.8100, 0.7255, 0.8155]
Our_model = [0.8534, 0.8917, 0.8200, 0.8255, 0.8055]

all_scores = [model_A_scores, model_B_scores, model_C_scores, model_D_scores, Our_model]

x_positions = np.arange(len(metrics))
num_models = len(model_names)
bar_width = 0.2
colors = ['lightblue', 'red', 'orange', 'pink', 'purple']

# 将画布变大，如 10英寸 x 7英寸
plt.figure(figsize=(10, 7), dpi=300)

for i, scores in enumerate(all_scores):
    offset = (i - (num_models - 1) / 2) * bar_width
    plt.bar(x_positions + offset, scores, width=bar_width, label=model_names[i], 
            edgecolor='black', color=colors[i])

plt.xticks(x_positions, metrics, rotation=45, ha='right')
plt.ylim([0.0, 1.0])
plt.title('Comparison of Model Performance Metrics', fontsize=10)
plt.ylabel('Score', fontsize=9)
plt.tick_params(axis='x', labelsize=6)
plt.tick_params(axis='y', labelsize=6)
plt.legend(fontsize=8)

for i, scores in enumerate(all_scores):
    offset = (i - (num_models - 1) / 2) * bar_width
    for j, v in enumerate(scores):
        plt.text(x_positions[j] + offset, v + 0.005, f"{v:.2f}", ha='center', 
                 color='black', fontsize=6, rotation=90)

plt.tight_layout()
plt.show()
